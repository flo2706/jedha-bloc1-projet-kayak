# %%
import pandas as pd

# %%
# Load the hotels JSON file into a DataFrame 
df = pd.read_json("../../Extract/hotels/data/hotels_descriptions.json")
df.head()
# Out:
#   location                                               name rating  \
# 0    Rouen  Sous les Etoiles - dans le plus haut gratte-ci...    9,2
# 1    Rouen  L'Oasis Rouennais - Hypercentre - Gare rive Ga...     10
# 2    Rouen                   Radisson Blu Hotel, Rouen Centre    8,9
# 3    Paris                                Studio à Montmartre    8,0
# 4    Paris              Apartment Cosy 3P Quartier République   None
#
#                                                  url  \
# 0  https://www.booking.com/hotel/fr/sous-les-etoi...
# 1  https://www.booking.com/hotel/fr/oasis-rouenna...
# 2  https://www.booking.com/hotel/fr/radisson-blu-...
# 3  https://www.booking.com/hotel/fr/studio-a-mont...
# 4  https://www.booking.com/hotel/fr/apartment-cos...
#
#                                          description  \
# 0  L’hébergement Sous les Etoiles - dans le plus ...
# 1  L’hébergement L'Oasis Rouennais - Hypercentre ...
# 2  L’établissement Radisson Blu Hotel, Rouen Cent...
# ...

# %%
# Inspect the list of unique cities in the dataset 
print(df["location"].unique())
# Out:
# ['Rouen' 'Paris' 'Le Mont-Saint-Michel' 'Chateau du Haut Koenigsbourg'
#  'Dijon' 'Annecy' 'Besancon' 'Eguisheim' 'Grenoble' 'Colmar' 'Strasbourg'
#  'Lille' 'Le Havre' 'Saint-Malo' 'Amiens' 'Bayeux' 'Gorges du Verdon'
#  'Bormes les Mimosas' 'Cassis' 'Uzes' 'N%C3%AEmes' 'Aigues Mortes'
#  'Carcassonne' 'Montauban' 'Toulouse' 'Ariege' 'Collioure' 'Marseille'
#  'Aix en Provence' 'Saintes Maries de la mer' 'Avignon' 'Lyon' 'Bayonne'
#  'Biarritz' 'La Rochelle']

# %%
# Count the number of hotels per city 
nbr_hotels_cities = df.groupby("location").count()
nbr_hotels_cities
# Out:
#                               name  rating  url  description  coordinates
# location
# Aigues Mortes                   25      25   25           25           25
# Aix en Provence                 25      23   25           25           25
# Amiens                          25      25   25           25           25
# Annecy                          25      25   25           25           25
# Ariege                          25      23   25           25           25
# Avignon                         25      25   25           25           25
# Bayeux                          25      25   25           25           25
# Bayonne                         25      25   25           25           25
# Besancon                        25      25   25           25           25
# Biarritz                        25      25   25           25           25
# Bormes les Mimosas              25      24   25           25           25
# Carcassonne                     25      25   25           25           25
# ...

# %%
df.shape
# Out:
# (875, 6)
